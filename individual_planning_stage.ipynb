# %% [markdown]
# DSCI Final Project
# Individual Planning Stage
# Brooke Armstrong

# %%
url1 = https://drive.google.com/file/d/1Mw9vW0hjTJwRWx0bDXiSpYsO3gKogaPz/edit
url2 = https://drive.google.com/file/d/14O91N5OlVkvdGxXNJUj5jIsV5RexhzbB/edit

# %% [markdown]
# Data Discription:

# %% [markdown]
# Question
# Question 1: What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?
#
# To answer this question, we will attempt to make a kNN classification model to predict whether or not someone will prescribe to the newsletter based on certain predictor variables. We will create these models with different combinations of predictor variables to determine which model provides the best accuracy/recall/percision
#
# We are going to look at predctor varuiables: age, (number of hours played? - probably not), gender, and experience
#
# Subscribed column is the class variable

# %% [markdown]
# Exploratory data analysis and visualization

# %% [markdown]
# Methods and plan:
#
# _ split data into training and test set
# - preprocess data to standardize it
#
#
# Why is this method appropriate?
#
# This question is a classification question, as we are looking to predict a certain variable, whether or not someone subscribes to a newsletter, based on other variables. We will be attemping to make a model that best predicts this given different player characteristics, and can use accuracy/percision/recall information to determine which combination of variables is best.
#
# Which assumptions are required, if any, to apply the method selected?
#
# We assume that we can use different K neighbours values for each model if our cross validation tests promote us to do so. Wee assume that we have relevant, unskewed data where all player types are represented relatively equally, so that this will not affect our data in any way.
#
# What are the potential limitations or weaknesses of the method selected?
# We are assuming that these are the only things that will influence newsletter subscription, there may be other factors at play that we do not know from the data set. KNN classification can be skewed by outliers or overrepresentation of certain player types
#
#
# How are you going to compare and select the model?
# - We will do K-NN classification for different combinations of predictor vairables, following the same steps of preprocessing and cross-validation. We will then compare each model to the test set to calculate accuracy, precision, and recall to determine which combination of predictors yeilds the most accurate predictions (with consideration of precision and recall as this an also provide important informaiton)
#
#   1. age and gender
#   2. age and experience
#   3. gender and experience
#   4. age, gender, and experience
#
#
# How are you going to process the data to apply the model? For example: Are you splitting the data? How? How many splits?
# - split the data into test and training set (25/75)
# - will split as first step
# - preform a 5 fold cross validation test
# - same random seed so the split
#
#
# What proportions will you use for the splits? At what stage will you split? Will there be a validation set? Will you use cross validation?
#
# - 25/75
# - right away so we are all working with same training and test sets
# - yes we will use cross validation
# - we will use the same training set to create each model so that we can better compare them against different vairables and reduce potential influence
